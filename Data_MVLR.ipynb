# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\Data_MVLR.csv")

# %%
mydata
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
mydata.shape
# Out:
# (48, 5)

# %%
import numpy as np

# %%
mydata.keys()
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
mydata.head(3)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561

# %%
i=mydata.iloc[:,:-1]

# %%
i
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
t=mydata["Petrol_Consumption"]

# %%
t
# Out:
# 0     541
# 1     524
# 2     561
# 3     414
# 4     410
# 5     457
# 6     344
# 7     467
# 8     464
# 9     498
# 10    580
# 11    471
# 12    525
# 13    508
# 14    566
# 15    635
# 16    603
# 17    714
# 18    865
# 19    640
# 20    649
# 21    540
# 22    464
# 23    547
# 24    460
# 25    566
# 26    577
# 27    631
# 28    574
# 29    534
# 30    571
# 31    554
# 32    577
# 33    628
# 34    487
# 35    644
# 36    640
# 37    704
# 38    648
# 39    968
# 40    587
# 41    699
# 42    632
# 43    591
# 44    782
# 45    510
# 46    610
# 47    524
# Name: Petrol_Consumption, dtype: int64

# %%
t.shape
# Out:
# (48,)

# %%
i.shape
# Out:
# (48, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(i,t,test_size=0.2)

# %%
xtrain.shape
# Out:
# (38, 4)

# %%
xtest.shape
# Out:
# (10, 4)

# %%
ytrain.shape
# Out:
# (38,)

# %%
ytest.shape
# Out:
# (10,)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(xtest,ytest,"*r")

# %%
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
mylin=LinearRegression()

# %%
x=xtrain.iloc[:,0:1]

# %%
x
# Out:
#     Petrol_tax
# 41        7.00
# 20        7.00
# 39        7.00
# 32        8.00
# 35        6.58
# 33        7.50
# 29        9.00
# 46        7.00
# 10        8.00
# 15        7.00
# 8         8.00
# 21        8.00
# 2         9.00
# 34        8.00
# 28        8.00
# 18        7.00
# 14        7.00
# 23        9.00
# 13        7.00
# 47        7.00
# 24        8.50
# 4         8.00
# 37        7.00
# 11        7.50
# 12        7.00
# 5        10.00
# 22        9.00
# 0         9.00
# 40        7.00
# 42        7.00
# 16        7.00
# 19        8.50
# 43        7.00
# 6         8.00
# 1         9.00
# 38        8.50
# 27        7.50
# 26        8.00

# %%
x1=xtrain.iloc[:,1:2]

# %%
x1
# Out:
#     Average_income
# 41            3656
# 20            4593
# 39            4345
# 32            3063
# 35            3802
# 33            3357
# 29            3601
# 46            4296
# 10            4391
# 15            4318
# 8             4447
# 21            4983
# 2             3865
# 34            3528
# 28            4188
# 18            4716
# 14            4332
# 23            4258
# 13            4207
# 47            5002
# 24            4574
# 4             4399
# 37            3897
# 11            5126
# 12            4817
# 5             5342
# 22            4897
# 0             3571
# 40            4449
# 42            4300
# 16            4206
# 19            4341
# 43            3745
# 6             5319
# 1             4092
# 38            3635
# 27            3846
# 26            3448

# %%
x2=xtrain.iloc[:,2:3]

# %%
x2
# Out:
#     Paved_Highways
# 41            3985
# 20            7834
# 39            3905
# 32            6524
# 35            7834
# 33            4121
# 29            4650
# 46            4083
# 10            5939
# 15           10340
# 8             8577
# 21             602
# 2             1586
# 34            3495
# 28            5975
# 18            5915
# 14            8159
# 23            4686
# 13            6580
# 47            9794
# 24            2619
# 4              431
# 37            6385
# 11           14186
# 12            6930
# 5             1333
# 22            2449
# 0             1976
# 40            4639
# 42            3635
# 16            8508
# 19            6010
# 43            2611
# 6            11868
# 1             1250
# 38            3274
# 27            9061
# 26            5399

# %%
x3=xtrain.iloc[:,-1:]

# %%
x3
# Out:
#     Population_Driver_licence(%)
# 41                         0.563
# 20                         0.663
# 39                         0.672
# 32                         0.578
# 35                         0.629
# 33                         0.547
# 29                         0.493
# 46                         0.623
# 10                         0.530
# 15                         0.586
# 8                          0.529
# 21                         0.602
# 2                          0.580
# 34                         0.487
# 28                         0.563
# 18                         0.724
# 14                         0.608
# 23                         0.517
# 13                         0.545
# 47                         0.593
# 24                         0.551
# 4                          0.544
# 37                         0.586
# 11                         0.525
# 12                         0.574
# 5                          0.571
# 22                         0.511
# ...

# %%
mymodel=mylin.fit(x,ytrain)
mymodel1=mylin.fit(x1,ytrain)
mymodel2=mylin.fit(x2,ytrain)
mymodel3=mylin.fit(x3,ytrain)

# %%
yp=mymodel.predict(x)
yp1=mymodel.predict(x1)
yp2=mymodel.predict(x2)
yp3=mymodel.predict(x3)

# %%
plt.plot(x,yp,"b")
plt.xlabel("Petrol_tax")
plt.ylabel("Petrol Consumption")
plt.show()

# %%
plt.plot(x1,yp1,"r")
plt.xlabel("Average_income")
plt.ylabel("Petrol Consumption")
plt.show()

# %%
plt.plot(x2,yp2,"g")
plt.xlabel("Paved_Highways")
plt.ylabel("Petrol Consumption")
plt.show()

# %%
plt.plot(x3,yp3,"y")
plt.xlabel("Population_Driver_licence(%)")
plt.ylabel("Petrol Consumption")
plt.show()
