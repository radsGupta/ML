# %%
import pandas as pd

# %%
import numpy as np

# %%
mydata=pd.read_csv(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\Housing_Data.csv")

# %%
mydata
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
mydata.keys()
# Out:
# Index(['Unnamed: 0', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'driveway', 'recroom', 'fullbase', 'gashw', 'airco', 'garagepl',
#        'prefarea'],
#       dtype='object')

# %%
mydata.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
i=mydata["lotsize"].values

# %%
i.shape
# Out:
# (546,)

# %%
t=mydata["price"].values

# %%
t.shape
# Out:
# (546,)

# %%
#data processing

# %%
type(i)
# Out:
# numpy.ndarray

# %%
i.shape
# Out:
# (546,)

# %%
inp=i.reshape(len(i),1)

# %%
t.shape
# Out:
# (546,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(i,t,test_size=0.2)

# %%
xtrain.shape
# Out:
# (436,)

# %%
ytrain.shape
# Out:
# (436,)

# %%
xtest.shape
# Out:
# (110,)

# %%
ytest.shape
# Out:
# (110,)

# %%
xtrain
# Out:
# array([ 4000,  6900,  4500,  6000,  3630,  3450,  7160,  4040, 16200,
#         2970,  3640,  9960,  2610,  6350,  7200,  4500,  5500,  5900,
#         9000,  6600,  9000,  3040,  4320,  7600,  2850,  4700,  6040,
#         4350,  4500,  3520,  4320,  4815,  7000,  5800,  5750,  3000,
#         6000,  6000,  7155,  6000,  4800,  3640,  3090,  3000,  3090,
#         4000,  4032, 10269,  4095,  4920,  4000,  2145,  5400,  7475,
#         3500,  4800,  1905,  6060,  5320,  3640,  2800,  4960,  5450,
#         3640,  4400,  3000,  3520,  3792,  6300,  5200,  3760,  5076,
#         4600,  3630,  6710,  5640,  6000,  8250,  4632,  5200,  1650,
#         3520,  2145,  8372,  3210,  7420,  4820,  3600,  6420,  3180,
#         4785,  2145,  4095,  4352,  3450,  2175,  2520,  4340,  3640,
#         6600,  6325,  9166,  6500,  9000,  8250,  3620,  9000,  4600,
#         4500,  5400,  2176,  4360,  8050,  5800,  2430,  5150,  3264,
# ...

# %%
ytrain
# Out:
# array([  65500.,   86000.,   46500.,   82500.,   52500.,   48500.,
#          84000.,   47500.,  145000.,   70000.,   65000.,  175000.,
#          49000.,   88500.,   90000.,   44900.,   75000.,   58000.,
#          90000.,  107000.,   45000.,   41000.,   67000.,   72000.,
#          52000.,   80000.,   69000.,   40500.,   51000.,   64500.,
#          46000.,   69000.,   82900.,   70000.,  140000.,   58000.,
#          98000.,   90000.,  124000.,  107500.,   71900.,   51000.,
#          44000.,   30500.,   43000.,   94500.,   61700.,   75000.,
#          45000.,   62900.,   97000.,   49500.,   79500.,  120000.,
#          62000.,   80000.,   62000.,   47000.,   49500.,   48500.,
#          38000.,   48000.,   88000.,   50000.,   37000.,   30000.,
#          60000.,   47000.,   70000.,   83000.,   65000.,   43000.,
#         127000.,   52500.,   77000.,   52500.,   89500.,   93000.,
#          59000.,   40750.,   45000.,   51900.,   47000.,   87000.,
# ...
