# %%
import pandas as pd
import numpy as np

# %%
mydata=pd.read_excel(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\Test_Data.xlsx")

# %%
mydata
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
mydata.shape
# Out:
# (15, 9)

# %%
mydata[3:6]
# Out:
#    account                              name                       street  \
# 3   109996       D'Amore, Gleichner and Bode  155 Fadel Crescent Apt. 144
# 4   121213                     Bauch-Goldner          7274 Marissa Common
# 5   132971  Williamson, Schumm and Hettinger         89403 Casimer Spring
#
#               city       state  postal-code     Jan     Feb    Mar
# 3       Hyattburgh       Maine        46021   45000  120000  10000
# 4  Shanahanchester  California        49681  162000  120000  35000
# 5     Jeremieburgh    Arkansas        62785  150000  120000  35000

# %%
mydata[3:6]
# Out:
#    account                              name                       street  \
# 3   109996       D'Amore, Gleichner and Bode  155 Fadel Crescent Apt. 144
# 4   121213                     Bauch-Goldner          7274 Marissa Common
# 5   132971  Williamson, Schumm and Hettinger         89403 Casimer Spring
#
#               city       state  postal-code     Jan     Feb    Mar
# 3       Hyattburgh       Maine        46021   45000  120000  10000
# 4  Shanahanchester  California        49681  162000  120000  35000
# 5     Jeremieburgh    Arkansas        62785  150000  120000  35000

# %%
mydata[2:5][["name","account"]]
# Out:
#                           name  account
# 2   Bashirian, Kunde and Price   648336
# 3  D'Amore, Gleichner and Bode   109996
# 4                Bauch-Goldner   121213

# %%
mydata['Jan']
# Out:
# 0      10000
# 1      95000
# 2      91000
# 3      45000
# 4     162000
# 5     150000
# 6      62000
# 7     145000
# 8      70000
# 9      70000
# 10     45000
# 11    150000
# 12    162000
# 13     55000
# 14    150000
# Name: Jan, dtype: int64

# %%
mydata.keys()
# Out:
# Index(['account', 'name', 'street', 'city', 'state', 'postal-code', 'Jan',
#        'Feb', 'Mar'],
#       dtype='object')

# %%
mydata.Jan
# Out:
# 0      10000
# 1      95000
# 2      91000
# 3      45000
# 4     162000
# 5     150000
# 6      62000
# 7     145000
# 8      70000
# 9      70000
# 10     45000
# 11    150000
# 12    162000
# 13     55000
# 14    150000
# Name: Jan, dtype: int64

# %%
mydata['Jan'].max()
# Out:
# 162000

# %%
mydata['Jan'][mydata['Jan']>91000]
# Out:
# 1      95000
# 4     162000
# 5     150000
# 7     145000
# 11    150000
# 12    162000
# 14    150000
# Name: Jan, dtype: int64

# %%
mydata['total']=mydata['Jan']+mydata['Feb']+mydata['Mar']

# %%
mydata['total']
# Out:
# 0     107000
# 1     175000
# 2     246000
# 3     175000
# 4     317000
# 5     305000
# 6     252000
# 7     275000
# 8     200000
# 9     225000
# 10    220000
# 11    322000
# 12    317000
# 13    210000
# 14    340000
# Name: total, dtype: int64

# %%
mydata
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
mydata["Jan"].describe()
# Out:
# count        15.000000
# mean      97466.666667
# std       51159.228558
# min       10000.000000
# 25%       58500.000000
# 50%       91000.000000
# 75%      150000.000000
# max      162000.000000
# Name: Jan, dtype: float64

# %%
mydata["Jan"].sum()
# Out:
# 1462000

# %%
mydata.iloc[:,:2]
# Out:
#     account                              name
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC

# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\Titanic_Data.xls")

# %%
mydata
# Out:
#    Rank           State_UT  Population  Rulal  Urban  Share  Growth  \
# 0     1      Uttar Pradesh   199812341  77.73  22.27  16.50   20.23
# 1     2        Maharashtra   112374333  54.78  45.22   9.28   15.99
# 2     3              Bihar   104099452  88.71  11.29   8.60   25.42
# 3     4        West Bengal    91276115  68.13  31.87   7.54   13.84
# 4     5     Andhra Pradesh    84580777  66.64  33.36   6.99   10.98
# 5     6     Madhya Pradesh    72626809  72.37  27.63   6.00   20.35
# 6     7         Tamil Nadu    72147030  51.60  48.40   5.96   15.61
# 7     8          Rajasthan    68548437  75.13  24.87   5.66   21.31
# 8     9          Karnataka    61095297  61.33  38.67   5.05   15.60
# 9    10            Gujarat    60439692  57.40  42.60   4.99   19.28
# 10   11             Odisha    41974218  83.31  16.69   3.47   14.05
# 11   12             Kerala    33406061  52.30  47.70   2.76    4.91
# 12   13          Jharkhand    32988134  75.95  24.05   2.72   22.42
# ...

# %%
mydata.keys()
# Out:
# Index(['Rank', 'State_UT', 'Population', 'Rulal', 'Urban', 'Share', 'Growth',
#        'Country', 'World_Rank'],
#       dtype='object')

# %%
mydata[mydata['Growth']==mydata.Growth.min()]
# Out:
#    Rank  State_UT  Population  Rulal  Urban  Share  Growth   Country  \
# 24   24  Nagaland     1978502  71.14  28.86   0.16   -0.58  Botswana
#
#     World_Rank
# 24         148

# %%
mydata.iloc[:,1:3]
# Out:
#              State_UT  Population
# 0       Uttar Pradesh   199812341
# 1         Maharashtra   112374333
# 2               Bihar   104099452
# 3         West Bengal    91276115
# 4      Andhra Pradesh    84580777
# 5      Madhya Pradesh    72626809
# 6          Tamil Nadu    72147030
# 7           Rajasthan    68548437
# 8           Karnataka    61095297
# 9             Gujarat    60439692
# 10             Odisha    41974218
# 11             Kerala    33406061
# 12          Jharkhand    32988134
# 13              Assam    31205576
# 14             Punjab    27743338
# 15       Chhattisgarh    25545198
# 16            Haryana    25351462
# 17              Delhi    16787941
# 18    Jammu & Kashmir    12541302
# 19        Uttarakhand    10086292
# 20   Himachal Pradesh     6864602
# 21            Tripura     3673917
# 22          Meghalaya     2966889
# 23            Manipur     2855794
# 24           Nagaland     1978502
# 25                Goa     1458545
# ...

# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\Titanic_Data.csv")

# %%
mydata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
male=mydata[mydata.Sex=='male']

# %%
male
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
male.shape
# Out:
# (577, 12)

# %%
ms=male[male.Survived==1]

# %%
ms.shape
# Out:
# (109, 12)

# %%
female=mydata[mydata.Sex=='female']

# %%
female.shape
# Out:
# (314, 12)

# %%
fs=female[female.Survived==1]

# %%
fs.shape
# Out:
# (233, 12)

# %%
pms=ms.shape[0]/male.shape[0]

# %%
pms
# Out:
# 0.18890814558058924

# %%
pfs=fs.shape[0]/female.shape[0]

# %%
pfs
# Out:
# 0.7420382165605095

# %%
men_survi=float(sum(male.Survived==1)/len(male))

# %%
men_survi
# Out:
# 0.18890814558058924
