# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\wine.xlsx")

# %% [markdown]
#  mydata=pd.read_excel(r"C:\Users\Rads Gupta\Downloads\DataSets-master\DataSets-master\wine.xlsx",names=["abc","def",.......)

# %%
mydata
# Out:
#      Class  Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# 5        1    14.20        1.76  2.45               15.2        112
# 6        1    14.39        1.87  2.45               14.6         96
# 7        1    14.06        2.15  2.61               17.6        121
# 8        1    14.83        1.64  2.17               14.0         97
# 9        1    13.86        1.35  2.27               16.0         98
# 10       1    14.10        2.16  2.30               18.0        105
# 11       1    14.12        1.48  2.32               16.8         95
# 12       1    13.75        1.73  2.41               16.0         89
# ...

# %%
i=mydata.iloc[:,1:]

# %%
t=mydata.iloc[:,0]

# %%
t.shape
# Out:
# (178,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(i,t,test_size=0.3,random_state=20)

# %%
#Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
myscale=StandardScaler()

# %%
X_xtrain=xtrain
X_xtest=xtest

# %%
myscale.fit(X_xtrain)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_xtrain.head(3)
# Out:
#      Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  Total Phenols  \
# 175    13.27        4.28  2.26               20.0        120           1.59
# 143    13.62        4.95  2.35               20.0         92           2.00
# 146    13.88        5.04  2.23               20.0         80           0.98
#
#      Flavanoids  Nonflavanoid Phenols  Proanthocyanins  Color intensity   Hue  \
# 175        0.69                  0.43             1.35             10.2  0.59
# 143        0.80                  0.47             1.02              4.4  0.91
# 146        0.34                  0.40             0.68              4.9  0.58
#
#      Diluted wines  Proline
# 175           1.56      835
# 143           2.05      550
# 146           1.33      415

# %%
type(X_xtrain)
# Out:
# pandas.core.frame.DataFrame

# %%
type(xtrain)
# Out:
# pandas.core.frame.DataFrame

# %%
X_xtrain=myscale.transform(X_xtrain)

# %%
type(X_xtrain)
# Out:
# numpy.ndarray

# %%
X_xtest=myscale.transform(X_xtest)

# %%
round(X_xtest.mean())
# Out:
# -0.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn=KNeighborsClassifier(n_neighbors=1)

# %%
mymodel=kn.fit(xtrain,ytrain
              )

# %%
yp=mymodel.predict(xtest)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(ytest,yp)
# Out:
# 0.7407407407407407

# %%
#how to drop a column

# %%
i1=mydata.drop(["Class"],axis=1)

# %%
i1.head(0)
# Out:
# Empty DataFrame
# Columns: [Alcohol, Malic Acid, Ash, Alcalinity of Ash, Magnesium, Total Phenols, Flavanoids, Nonflavanoid Phenols, Proanthocyanins, Color intensity, Hue, Diluted wines, Proline]
# Index: []

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()

# %%
mymodel1=gnb.fit(xtrain,ytrain)

# %%
yp1=mymodel1.predict(xtest)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(ytest,yp1)
# Out:
# 0.98148148148148151

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb=MultinomialNB()

# %%
mymodel2=mnb.fit(xtrain,ytrain)

# %%
yp2=mymodel2.predict(xtest)

# %%
metrics.accuracy_score(ytest,yp2)
# Out:
# 0.85185185185185186

# %% [markdown]
# # USING MLP CLASSIFIER

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp=MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500)

# %%
mymodel3=mlp.fit(X_xtrain,ytrain)

# %%
yp4=mymodel3.predict(X_xtest)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(ytest,yp4)
# Out:
# 0.98148148148148151

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
classification_report(ytest,yp4)
# Out:
# '             precision    recall  f1-score   support\n\n          1       1.00      1.00      1.00        15\n          2       1.00      0.96      0.98        27\n          3       0.92      1.00      0.96        12\n\navg / total       0.98      0.98      0.98        54\n'

# %%
confusion_matrix(ytest,yp4)
# Out:
# array([[15,  0,  0],
#        [ 0, 26,  1],
#        [ 0,  0, 12]])

# %%
#more than 2 classes that is y Multi layer perceptron.used

# %%
len(mymodel3.coefs_) #dominating features
# Out:
# 4

# %%
mymodel3.coefs_
# Out:
# [array([[  5.27777481e-01,   6.78490387e-01,  -3.90329553e-01,
#           -1.90194901e-01,   1.32741093e-01,  -3.34569986e-01,
#           -7.86961047e-02,  -2.80902098e-01,  -5.31717056e-01,
#            6.31069409e-02,   2.28967706e-02,   1.76888219e-01,
#            5.76522907e-02],
#         [  1.34255886e-01,  -1.73127051e-01,  -4.62290278e-01,
#            1.99153350e-01,  -3.92793867e-01,   5.45693631e-01,
#           -1.17824291e-01,   1.97552137e-02,  -5.97926840e-02,
#           -3.98416294e-01,   1.53319702e-01,  -1.79321184e-01,
#           -2.80578353e-01],
#         [ -5.22004846e-02,  -1.03352175e-01,  -2.68173115e-01,
#            2.94815377e-01,  -3.92809673e-01,   4.91704278e-01,
#           -5.12930308e-01,  -2.84217588e-01,  -5.67331805e-01,
#           -3.07581959e-01,  -1.57549178e-01,  -4.68684789e-01,
#            3.67792877e-01],
#         [  1.64906918e-01,  -1.12533691e-01,   3.89721625e-01,
#            5.73076876e-01,   8.94804152e-02,   5.63272893e-01,
# ...

# %%
mymodel3.intercepts_[0] #bias
# Out:
# array([-0.1511429 ,  0.532899  ,  0.47521486, -0.11317428,  0.36085162,
#         0.03378713,  0.13529297,  0.169396  ,  0.01355455,  0.50102698,
#         0.60025486,  0.08308897,  0.32768979])

# %%
mymodel3.coefs_[0]  #weight at each node
# Out:
# array([[  5.27777481e-01,   6.78490387e-01,  -3.90329553e-01,
#          -1.90194901e-01,   1.32741093e-01,  -3.34569986e-01,
#          -7.86961047e-02,  -2.80902098e-01,  -5.31717056e-01,
#           6.31069409e-02,   2.28967706e-02,   1.76888219e-01,
#           5.76522907e-02],
#        [  1.34255886e-01,  -1.73127051e-01,  -4.62290278e-01,
#           1.99153350e-01,  -3.92793867e-01,   5.45693631e-01,
#          -1.17824291e-01,   1.97552137e-02,  -5.97926840e-02,
#          -3.98416294e-01,   1.53319702e-01,  -1.79321184e-01,
#          -2.80578353e-01],
#        [ -5.22004846e-02,  -1.03352175e-01,  -2.68173115e-01,
#           2.94815377e-01,  -3.92809673e-01,   4.91704278e-01,
#          -5.12930308e-01,  -2.84217588e-01,  -5.67331805e-01,
#          -3.07581959e-01,  -1.57549178e-01,  -4.68684789e-01,
#           3.67792877e-01],
#        [  1.64906918e-01,  -1.12533691e-01,   3.89721625e-01,
#           5.73076876e-01,   8.94804152e-02,   5.63272893e-01,
# ...
